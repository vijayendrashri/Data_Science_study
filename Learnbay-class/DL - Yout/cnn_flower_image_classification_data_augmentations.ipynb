# %% [markdown]
# <h2 style='color:blue' align='center'>Data Augmentation To Address Overfitting In Flower Classification CNN</h2>

# %% [markdown]
# **In this notebook we will build a CNN to classify flower images. We will also see how our model overfits and how overfitting can be addressed using data augmentation. Data augmentation is a process of generating new training samples from current training dataset using transformations such as zoom, rotations, change in contrast etc**

# %% [markdown]
# Credits: I used tensorflow offical tutorial: https://www.tensorflow.org/tutorials/images/classification as a reference and made bunch of changes to make it simpler

# %% [markdown]
# In below image, 4 new training samples are generated from original sample using different transformations

# %% [markdown]
# <img src="daisy2.JPG" />

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# We will download flowers dataset from google website and store it locally. In below call it downloads the zip file (.tgz) in cache_dir which is . meaning the current folder

# %% [markdown]
# <h3 style='color:purple'>Load flowers dataset</h3>

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data. I specified . which means current directory
# untar true will unzip it

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/dandelion/16716172029_2166d8717f_m.jpg'),
#  PosixPath('datasets/flower_photos/dandelion/570127230_ce409f90f8_n.jpg'),
#  PosixPath('datasets/flower_photos/dandelion/17135145776_4c2ec21b05_m.jpg'),
#  PosixPath('datasets/flower_photos/dandelion/2963905796_227d37ff12.jpg'),
#  PosixPath('datasets/flower_photos/dandelion/7465850028_cdfaae235a_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/174109630_3c544b8a2f.jpg'),
#  PosixPath('datasets/flower_photos/roses/4702438868_278b9cf41c_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5961803532_9368212949_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/6363951285_a802238d4e.jpg'),
#  PosixPath('datasets/flower_photos/roses/14414117598_cf70df30de.jpg')]

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x251 at 0x7F1D404156A0>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F1CAF52ED30>

# %% [markdown]
# <h3 style='color:purple'>Read flowers images from disk into numpy array using opencv</h3>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/174109630_3c544b8a2f.jpg'),
#  PosixPath('datasets/flower_photos/roses/4702438868_278b9cf41c_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5961803532_9368212949_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/6363951285_a802238d4e.jpg'),
#  PosixPath('datasets/flower_photos/roses/14414117598_cf70df30de.jpg')]

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets/flower_photos/roses/174109630_3c544b8a2f.jpg'

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
cv2.resize(img,(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %% [markdown]
# <h3 style='color:purple'>Train test split</h3>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# <h3 style='color:purple'>Preprocessing: scale images</h3>

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %% [markdown]
# <h3 style='color:purple'>Build convolutional neural network and train it</h3>

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=10)
# Out:
# Epoch 1/10
# 86/86 [==============================] - 42s 479ms/step - loss: 1.2976 - accuracy: 0.4444
# Epoch 2/10
# 86/86 [==============================] - 41s 474ms/step - loss: 0.9440 - accuracy: 0.6301
# Epoch 3/10
# 86/86 [==============================] - 42s 491ms/step - loss: 0.8202 - accuracy: 0.6690
# Epoch 4/10
# 86/86 [==============================] - 42s 492ms/step - loss: 0.5969 - accuracy: 0.7831
# Epoch 5/10
# 86/86 [==============================] - 40s 470ms/step - loss: 0.3984 - accuracy: 0.8579
# Epoch 6/10
# 86/86 [==============================] - 41s 476ms/step - loss: 0.2554 - accuracy: 0.9179
# Epoch 7/10
# 86/86 [==============================] - 37s 431ms/step - loss: 0.1587 - accuracy: 0.9488
# Epoch 8/10
# 86/86 [==============================] - 40s 467ms/step - loss: 0.0947 - accuracy: 0.9724
# Epoch 9/10
# 86/86 [==============================] - 41s 472ms/step - loss: 0.0347 - accuracy: 0.9920
# Epoch 10/10
# 86/86 [==============================] - 41s 481ms/step - loss: 0.0162 - accuracy: 0.9982

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 6s 195ms/step - loss: 2.1548 - accuracy: 0.6405
# [2.1547653675079346, 0.6405228972434998]

# %% [markdown]
# **Here we see that while train accuracy is very high (99%), the test accuracy is significantly low (66.99%) indicating overfitting. Let's make some predictions before we use data augmentation to address overfitting**

# %%
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([[  6.603801  ,  12.503002  ,   1.6132145 ,  -1.794517  ,
#          -4.7844367 ],
#        [  2.9037588 ,  13.5272455 ,  -6.529939  ,  -2.6371224 ,
#           6.3183103 ],
#        [  0.41731396,  -1.7533913 ,   2.6455355 ,   0.9313841 ,
#          -0.3175946 ],
#        ...,
#        [ -3.4647007 ,  -1.5524869 ,  -2.4793484 ,  13.657665  ,
#           8.926111  ],
#        [ 13.439201  ,  -1.0782802 , -11.786718  ,  -8.517658  ,
#           8.424987  ],
#        [ -2.8304706 ,  -4.9734573 ,   6.3431396 ,  15.337693  ,
#           4.3597026 ]], dtype=float32)

# %%
score = tf.nn.softmax(predictions[0])

# %%
np.argmax(score)
# Out:
# 1

# %%
y_test[0]
# Out:
# 1

# %% [markdown]
# <h3 style='color:purple'>Improve Test Accuracy Using Data Augmentation</h3>

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal"),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# **Original Image**

# %%
plt.axis('off')
plt.imshow(X[0])

# %% [markdown]
# **Newly generated training sample using data augmentation**

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-39-7c5c72693feb> in <module>
#       1 plt.axis('off')
# ----> 2 plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     378       if not self.built:
#     379         self._init_graph_network(self.inputs, self.outputs)
# --> 380       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     381
#     382     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     418         a list of tensors if there are more than one outputs.
#     419     """
# --> 420     return self._run_internal_graph(
#     421         inputs, training=training, mask=mask)
#     422
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     554
#     555         args, kwargs = node.map_arguments(tensor_dict)
# --> 556         outputs = node.layer(*args, **kwargs)
#     557
#     558         # Update tensor_dict.
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/layers/preprocessing/image_preprocessing.py in call(self, inputs, training)
#     405       return flipped_outputs
#     406
# --> 407     output = control_flow_util.smart_cond(training, random_flipped_inputs,
#     408                                           lambda: inputs)
#     409     output.set_shape(inputs.shape)
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/utils/control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     107     return control_flow_ops.cond(
#     108         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 109   return smart_module.smart_cond(
#     110       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     111
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/keras/layers/preprocessing/image_preprocessing.py in random_flipped_inputs()
#     398       flipped_outputs = inputs
#     399       if self.horizontal:
# --> 400         flipped_outputs = image_ops.random_flip_left_right(
#     401             flipped_outputs, self.seed)
#     402       if self.vertical:
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/ops/image_ops_impl.py in random_flip_left_right(image, seed)
#     421   """
#     422   random_func = functools.partial(random_ops.random_uniform, seed=seed)
# --> 423   return _random_flip(image, 1, random_func, 'random_flip_left_right')
#     424
#     425
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/ops/image_ops_impl.py in _random_flip(image, flip_index, random_func, scope_name)
#     534       return f_rank3()
#     535     elif shape.ndims == 4:
# --> 536       return f_rank4()
#     537     else:
#     538       raise ValueError(
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/ops/image_ops_impl.py in f_rank4()
#     520
#     521     def f_rank4():
# --> 522       batch_size = array_ops.shape(image)[0]
#     523       uniform_random = random_func(shape=[batch_size], minval=0, maxval=1.0)
#     524       flips = math_ops.round(
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in shape(input, name, out_type)
#     648     A `Tensor` of type `out_type`.
#     649   """
# --> 650   return shape_internal(input, name, optimize=True, out_type=out_type)
#     651
#     652
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in shape_internal(input, name, optimize, out_type)
#     676         if optimize and input_shape.is_fully_defined():
#     677           return constant(input_shape.as_list(), out_type, name=name)
# --> 678       return gen_array_ops.shape(input, name=name, out_type=out_type)
#     679
#     680
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py in shape(input, out_type, name)
#    9179       return _result
#    9180     except _core._NotOkStatusException as e:
# -> 9181       _ops.raise_from_not_ok_status(e, name)
#    9182     except _core._FallbackException:
#    9183       pass
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6895   message = e.message + (" name: " + name if name is not None else "")
#    6896   # pylint: disable=protected-access
# -> 6897   six.raise_from(core._status_to_exception(e.code, message), None)
#    6898   # pylint: enable=protected-access
#    6899
#
# ~/anaconda3/envs/TF/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run Shape: Dst tensor is not initialized. [Op:Shape]

# %% [markdown]
# <h3 style='color:purple'>Train the model using data augmentation and a drop out layer</h3>

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 [==============================] - 1s 17ms/step - loss: 1.4347 - accuracy: 0.3844
# Epoch 2/30
# 86/86 [==============================] - 1s 16ms/step - loss: 1.0742 - accuracy: 0.5789
# Epoch 3/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.9900 - accuracy: 0.6130
# Epoch 4/30
# 86/86 [==============================] - 1s 13ms/step - loss: 0.9247 - accuracy: 0.6421
# Epoch 5/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.8485 - accuracy: 0.6722
# Epoch 6/30
# 86/86 [==============================] - 1s 16ms/step - loss: 0.8226 - accuracy: 0.6893
# Epoch 7/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.7964 - accuracy: 0.6944
# Epoch 8/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.7662 - accuracy: 0.7140
# Epoch 9/30
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7292 - accuracy: 0.7249
# Epoch 10/30
# 86/86 [==============================] - 2s 18ms/step - loss: 0.6941 - accuracy: 0.7362
# Epoch 11/30
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6790 - accuracy: 0.7493
# Epoch 12/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.6635 - accuracy: 0.7493
# Epoch 13/30
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6291 - accuracy: 0.7569
# Epoch 14/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.6228 - accuracy: 0.7576
# Epoch 15/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.5804 - accuracy: 0.7794
# Epoch 16/30
# 86/86 [==============================] - 1s 16ms/step - loss: 0.5631 - accuracy: 0.7823
# Epoch 17/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.5718 - accuracy: 0.7733
# Epoch 18/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.5463 - accuracy: 0.8005
# Epoch 19/30
# 86/86 [==============================] - 1s 13ms/step - loss: 0.5400 - accuracy: 0.7896
# Epoch 20/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.5010 - accuracy: 0.7991
# Epoch 21/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.4985 - accuracy: 0.8118
# Epoch 22/30
# 86/86 [==============================] - 1s 12ms/step - loss: 0.4548 - accuracy: 0.8223
# Epoch 23/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.4563 - accuracy: 0.8256
# Epoch 24/30
# 86/86 [==============================] - 1s 13ms/step - loss: 0.4497 - accuracy: 0.8278
# Epoch 25/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.4303 - accuracy: 0.8412
# Epoch 26/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.4215 - accuracy: 0.8368
# Epoch 27/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.3803 - accuracy: 0.8594
# Epoch 28/30
# 86/86 [==============================] - 1s 15ms/step - loss: 0.3934 - accuracy: 0.8510
# Epoch 29/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.3724 - accuracy: 0.8583
# Epoch 30/30
# 86/86 [==============================] - 1s 14ms/step - loss: 0.3767 - accuracy: 0.8594

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 0s 5ms/step - loss: 0.8419 - accuracy: 0.7375
# [0.8418797850608826, 0.7374727725982666]

# %% [markdown]
# **You can see that by using data augmentation and drop out layer the accuracy of test set predictions is increased to 73.74%**

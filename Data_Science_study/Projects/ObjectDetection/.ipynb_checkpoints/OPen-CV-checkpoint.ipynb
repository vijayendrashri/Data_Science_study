# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('image.jpeg')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (461, 768, 3)

# %%
plt.imshow(image)

# %%
cv2.cvtColor(image,cv2.COLOR_BG2BGR)

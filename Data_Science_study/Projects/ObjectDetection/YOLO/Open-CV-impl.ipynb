# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('image.jpeg')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (461, 768, 3)

# %%
plt.imshow(image)

# %%
new_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(new_image)

# %%
r,g,b = cv2.split(new_image)
print('r',r.shape)
print('g',g)
print('b',b)
# Out:
# r (461, 768)
# g [[ 64  62  59 ... 102 100 104]
#  [ 69  64  63 ... 102 105 110]
#  [ 77  68  68 ... 114 115 118]
#  ...
#  [129 135 139 ... 141 143 139]
#  [137 134 134 ...  96 103 107]
#  [146 135 133 ... 107 123 139]]
# b [[ 60  58  55 ...  90  88  92]
#  [ 65  60  59 ...  90  93  98]
#  [ 73  64  64 ... 102 101 104]
#  ...
#  [132 138 142 ... 139 143 139]
#  [140 137 137 ...  99 107 111]
#  [149 138 136 ... 114 132 148]]

# %%
mer_image =cv2.merge((r,g,b))

# %%
s=50
w=int(new_image.shape[1]*s/100)
h=int(new_image.shape[0]*s/100)

# %%
dim = (w,h)
re_size=cv2.resize(new_image,dim,interpolation=cv2.INTER_AREA)

# %%
plt.imshow(re_size)

# %%
re_size.shape
# Out:
# (230, 384, 3)

# %%
(h,w)=new_image.shape[:2]
c=(w/2,h/2)
angle=90
m = cv2.getRotationMatrix2D(c,angle,1.0)
rotate_90=cv2.warpAffine(new_image,m,(h,w))

# %%
plt.imshow(rotate_90)

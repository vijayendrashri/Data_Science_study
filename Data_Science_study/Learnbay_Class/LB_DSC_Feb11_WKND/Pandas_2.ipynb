# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/international_org.csv')
df
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
# Add column to dataframe
df['city'] = 'Banglore'

# %%
df
# Out:
#   Organization Name  Headquater      city
# 0               FAO        Rome  Banglore
# 1               ICJ   The Hague  Banglore
# 2               IMF  Washington  Banglore
# 3            UNESCO       Paris  Banglore
# 4               UNO    New York  Banglore
# 5        World Bank  Washington  Banglore

# %%
df['city'] = ['Banglore','Banglore1','Banglore2','Banglore3','Banglore4','Banglore5']

# %%
df['city']
# Out:
# 0     Banglore
# 1    Banglore1
# 2    Banglore2
# 3    Banglore3
# 4    Banglore4
# 5    Banglore5
# Name: city, dtype: object

# %%
imdb = pd.read_csv('dataset/imdb_rating.csv')
imdb
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
imdb['actor']='vikey'
imdb
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration  actor
# 0       142  vikey
# 1       175  vikey
# 2       200  vikey
# 3       152  vikey
# 4       154  vikey
# 5        96  vikey
# 6       161  vikey
# ...

# %%
imdb['duration'][3]=50
imdb['asdas']=20202
# Out:
# <ipython-input-9-5b4fd3816a92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb['duration'][3]=50

# %%
imdb
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration  actor  asdas
# 0       142  vikey  20202
# 1       175  vikey  20202
# 2       200  vikey  20202
# 3        50  vikey  20202
# 4       154  vikey  20202
# ...

# %%
imdb.drop('asdas',axis=1,inplace=True)

# %% [markdown]
# # Access particular row

# %%
imdb.loc[1:2]
# Out:
#    star_rating                   title  genre  duration  actor
# 1          9.2           The Godfather  Crime       175  vikey
# 2          9.1  The Godfather: Part II  Crime       200  vikey

# %%
imdb.loc[10]=[2,2,4,6,6]

# %%
imdb
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          2.0                                              2          4
#
#     duration  actor
# 0        142  vikey
# 1        175  vikey
# ...

# %%
imdb.index.max()
# Out:
# 10

# %%
# update single value on a column
imdb.at[5, 'actor'] = 'xyz'

# %%
imdb
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          2.0                                              2          4
#
#     duration  actor
# 0        142  vikey
# 1        175  vikey
# ...

# %%
imdb = pd.read_csv('dataset/imdb_rating.csv')
imdb
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
list(imdb.star_rating).index(imdb.star_rating.max())
# Out:
# 0

# %%
# Get max rating and change title to 'XXX'
imdb.at[list(imdb.star_rating).index(imdb.star_rating.max()), 'title'] = 'xxx'

# %%
imdb
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                                            xxx      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
a=imdb.groupby(by=['genre']).count()

# %%
a
# Out:
#            star_rating  title  duration
# genre
# Action               1      1         1
# Adventure            1      1         1
# Biography            1      1         1
# Crime                4      4         4
# Drama                2      2         2
# Western              1      1         1

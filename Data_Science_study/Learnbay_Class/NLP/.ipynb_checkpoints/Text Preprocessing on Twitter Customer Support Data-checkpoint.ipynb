# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# In any machine learning task, cleaning or preprocessing the data is as important as model building if not more. And when it comes to unstructured data like text, this process is even more important.
#
# Objective of this code is to understand the various text preprocessing steps with examples.
#
# Some of the common text preprocessing / cleaning steps are:
#
# * Lower casing
# * Removal of Punctuations
# * Removal of Stopwords
# * Removal of Frequent words
# * Removal of Rare words
# * Number to words/ignoring numbers
# * Stemming
# * Lemmatization
# * Removal of emojis
# * Removal of emoticons
# * Conversion of emoticons to words
# * Conversion of emojis to words
# * Removal of URLs
# * Removal of HTML tags
# * Chat words conversion
# * Spelling correction
#
#
# So these are the different types of text preprocessing steps which we can do on text data. But we need not do all of these all the times. We need to carefully choose the preprocessing steps based on our use case since that also play an important role.
#
# For example, in sentiment analysis use case, we need not remove the emojis or emoticons as it will convey some important information about the sentiment. Similarly we need to decide based on our use cases.

# %%
import pandas as pd
import re
import nltk
import spacy
import string

# %%
from google.colab import drive  # while working on colab only
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! ls "/content/drive/My Drive/data"
# Out:
# creditcard.csv	dataset  pubg  twcs.csv  uci-news-aggregator.csv

# %%
full_df = pd.read_csv("twcs.csv", nrows=100000)
df = full_df[["text"]]
df["text"] = df["text"].astype(str)
full_df.head()
# Out:
# <ipython-input-3-08d488f404dd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text"] = df["text"].astype(str)
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %% [markdown]
# 1. Lower case conversion

# %%
df["text_lower"] = df.loc[:,"text"].str.lower()
df.head()
# Out:
# <ipython-input-13-b63e6f15891a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_lower"] = df.loc[:,"text"].str.lower()
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.

# %%
df.head(25)
# Out:
#                                                  text  \
# 0   @115712 I understand. I would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare I have sent several private messag...
# 3   @115712 Please send us a Private Message so th...
# 4                                  @sprintcare I did.
# 5   @115712 Can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 This is saddening to hear. Please shoo...
# 8   @sprintcare You gonna magically change your co...
# 9   @115713 We understand your concerns and we'd l...
# 10  @sprintcare Since I signed up with you....Sinc...
# 11  @115713 H there! We'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 Please send me a private message so th...
# 14  @115714 whenever I contact customer support, t...
# 15         @115716 What information is incorrect? ^JK
# 16  @Ask_Spectrum Would you like me to email you a...
# 17  @115716 Our department is part of the corporat...
# 18  @Ask_Spectrum I received this from your corpor...
# 19                          @115716 No thank you. ^JK
# 20  @Ask_Spectrum The correct way to do it is via ...
# 21  @Ask_Spectrum That is INCORRECT information I ...
# 22  @115716 The information pertaining to the acco...
# 23  actually that's a broken link you sent me and ...
# 24  @115717 Hello, My apologies for any frustratio...
#
#                                            text_lower
# 0   @115712 i understand. i would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare i have sent several private messag...
# 3   @115712 please send us a private message so th...
# 4                                  @sprintcare i did.
# 5   @115712 can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 this is saddening to hear. please shoo...
# 8   @sprintcare you gonna magically change your co...
# 9   @115713 we understand your concerns and we'd l...
# 10  @sprintcare since i signed up with you....sinc...
# 11  @115713 h there! we'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 please send me a private message so th...
# 14  @115714 whenever i contact customer support, t...
# 15         @115716 what information is incorrect? ^jk
# 16  @ask_spectrum would you like me to email you a...
# 17  @115716 our department is part of the corporat...
# 18  @ask_spectrum i received this from your corpor...
# 19                          @115716 no thank you. ^jk
# 20  @ask_spectrum the correct way to do it is via ...
# 21  @ask_spectrum that is incorrect information i ...
# 22  @115716 the information pertaining to the acco...
# 23  actually that's a broken link you sent me and ...
# 24  @115717 hello, my apologies for any frustratio...

# %% [markdown]
# 2. Removal of Stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/vijay/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["text_wo_stop"] = df["text_lower"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
# <ipython-input-20-9d8f99401081>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_wo_stop"] = df["text_lower"].apply(lambda text: remove_stopwords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.

# %% [markdown]
# 3. Remove Punctuations

# %%
# drop the new column created in last cell
# df.drop(["text_lower"], axis=1, inplace=True)

PUNCT_TO_REMOVE = string.punctuation
print (PUNCT_TO_REMOVE)
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df.loc[:,"text_wo_punct"] = df["text_wo_stop"].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# /home/vijay/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop  \
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.
#
#                                        text_wo_punct
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist y...
# 4                                     sprintcare did

# %%
df.head(25)
# Out:
#                                                  text  \
# 0   @115712 I understand. I would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare I have sent several private messag...
# 3   @115712 Please send us a Private Message so th...
# 4                                  @sprintcare I did.
# 5   @115712 Can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 This is saddening to hear. Please shoo...
# 8   @sprintcare You gonna magically change your co...
# 9   @115713 We understand your concerns and we'd l...
# 10  @sprintcare Since I signed up with you....Sinc...
# 11  @115713 H there! We'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 Please send me a private message so th...
# 14  @115714 whenever I contact customer support, t...
# 15         @115716 What information is incorrect? ^JK
# 16  @Ask_Spectrum Would you like me to email you a...
# 17  @115716 Our department is part of the corporat...
# 18  @Ask_Spectrum I received this from your corpor...
# 19                          @115716 No thank you. ^JK
# 20  @Ask_Spectrum The correct way to do it is via ...
# 21  @Ask_Spectrum That is INCORRECT information I ...
# 22  @115716 The information pertaining to the acco...
# 23  actually that's a broken link you sent me and ...
# 24  @115717 Hello, My apologies for any frustratio...
#
#                                            text_lower  \
# 0   @115712 i understand. i would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare i have sent several private messag...
# 3   @115712 please send us a private message so th...
# 4                                  @sprintcare i did.
# 5   @115712 can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 this is saddening to hear. please shoo...
# 8   @sprintcare you gonna magically change your co...
# 9   @115713 we understand your concerns and we'd l...
# 10  @sprintcare since i signed up with you....sinc...
# 11  @115713 h there! we'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 please send me a private message so th...
# 14  @115714 whenever i contact customer support, t...
# 15         @115716 what information is incorrect? ^jk
# 16  @ask_spectrum would you like me to email you a...
# 17  @115716 our department is part of the corporat...
# 18  @ask_spectrum i received this from your corpor...
# 19                          @115716 no thank you. ^jk
# 20  @ask_spectrum the correct way to do it is via ...
# 21  @ask_spectrum that is incorrect information i ...
# 22  @115716 the information pertaining to the acco...
# 23  actually that's a broken link you sent me and ...
# 24  @115717 hello, my apologies for any frustratio...
#
#                                          text_wo_stop  \
# 0   @115712 understand. would like assist you. wou...
# 1                                 @sprintcare propose
# 2   @sprintcare sent several private messages one ...
# 3   @115712 please send us private message assist ...
# 4                                    @sprintcare did.
# 5   @115712 please send us private message, gain d...
# 6                  @sprintcare worst customer service
# 7   @115713 saddening hear. please shoot us dm, lo...
# 8   @sprintcare gonna magically change connectivit...
# 9   @115713 understand concerns we'd like please s...
# 10        @sprintcare since signed you....since day 1
# 11  @115713 h there! we'd definitely like work thi...
# 12  @115714 y’all lie “great” connection. 5 bars l...
# 13  @115715 please send private message send link ...
# 14  @115714 whenever contact customer support, tel...
# 15                 @115716 information incorrect? ^jk
# 16  @ask_spectrum would like email copy one since ...
# 17  @115716 department part corporate office. part...
# 18  @ask_spectrum received corporate office would ...
# 19                             @115716 thank you. ^jk
# 20  @ask_spectrum correct way via ocs account take...
# 21  @ask_spectrum incorrect information form front...
# 22  @115716 information pertaining account assumpt...
# 23  actually that's broken link sent incorrect inf...
# 24  @115717 hello, apologies frustrations inconven...
#
#                                         text_wo_punct
# 0   115712 understand would like assist you would ...
# 1                                  sprintcare propose
# 2   sprintcare sent several private messages one r...
# 3   115712 please send us private message assist y...
# 4                                      sprintcare did
# 5   115712 please send us private message gain det...
# 6                   sprintcare worst customer service
# 7   115713 saddening hear please shoot us dm look ...
# 8   sprintcare gonna magically change connectivity...
# 9   115713 understand concerns wed like please sen...
# 10             sprintcare since signed yousince day 1
# 11  115713 h there wed definitely like work this l...
# 12  115714 y’all lie “great” connection 5 bars lte...
# 13  115715 please send private message send link a...
# 14  115714 whenever contact customer support tell ...
# 15                    115716 information incorrect jk
# 16  askspectrum would like email copy one since sp...
# 17  115716 department part corporate office partic...
# 18  askspectrum received corporate office would li...
# 19                                115716 thank you jk
# 20  askspectrum correct way via ocs account takeov...
# 21  askspectrum incorrect information form front f...
# 22  115716 information pertaining account assumpti...
# 23  actually thats broken link sent incorrect info...
# 24  115717 hello apologies frustrations inconvenie...

# %% [markdown]
# 4. Removal of Frequent words

# %%
from collections import Counter
cnt = Counter()
for text in df["text_wo_punct"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('us', 15280),
#  ('please', 14172),
#  ('dm', 10290),
#  ('help', 9181),
#  ('hi', 8364),
#  ('thanks', 7794),
#  ('get', 7393),
#  ('sorry', 6913),
#  ('you', 6354),
#  ('amazonhelp', 5916)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["text_wo_stopfreq"] = df["text_wo_punct"].apply(lambda text: remove_freqwords(text))
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop  \
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.
#
#                                        text_wo_punct  \
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist y...
# 4                                     sprintcare did
#
#                                     text_wo_stopfreq  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                 text_wo_stopfreqrare  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                         text_stemmed  \
# 0  115712 understand would like assist would need...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click messag ...
# 4                                      sprintcar did
#
#                                      text_lemmatized
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private message one re...
# 3  115712 please send u private message assist yo...
# 4                                     sprintcare did

# %% [markdown]
# 5. Removal of Rare words

# %%
# Drop the two columns which are no more needed 
# df.drop(["text_wo_punct", "text_wo_stop"], axis=1, inplace=True)

n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])
print(RAREWORDS)
def remove_rarewords(text):
    """custom function to remove the rare words"""
    return " ".join([word for word in str(text).split() if word not in RAREWORDS])

df["text_wo_stopfreqrare"] = df["text_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
df.head()
# Out:
# {'phone131027', '230k', '144295', '144296', 'therelets', '7109', '7110', 'httpstcoklebhaiotk', 'mailtemplate', 'httpstcosxccepn7bl'}
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop  \
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.
#
#                                        text_wo_punct  \
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist y...
# 4                                     sprintcare did
#
#                                     text_wo_stopfreq  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                 text_wo_stopfreqrare  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                         text_stemmed  \
# 0  115712 understand would like assist would need...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click messag ...
# 4                                      sprintcar did
#
#                                      text_lemmatized
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private message one re...
# 3  115712 please send u private message assist yo...
# 4                                     sprintcare did

# %% [markdown]
# 6. Stemming

# %%
from nltk.stem.snowball import SnowballStemmer

# Drop the two columns 
# df.drop(["text_wo_stopfreq", "text_wo_stopfreqrare"], axis=1, inplace=True) 

stemmer = SnowballStemmer("english")
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

df["text_stemmed"] = df["text_wo_stopfreq"].apply(lambda text: stem_words(text))
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop  \
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.
#
#                                        text_wo_punct  \
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist y...
# 4                                     sprintcare did
#
#                                     text_wo_stopfreq  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                 text_wo_stopfreqrare  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                         text_stemmed  \
# 0  115712 understand would like assist would need...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click messag ...
# 4                                      sprintcar did
#
#                                      text_lemmatized
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private message one re...
# 3  115712 please send u private message assist yo...
# 4                                     sprintcare did

# %% [markdown]
# 7. Lemmatization

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/vijay/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df["text_lemmatized"] = df["text_wo_punct"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop  \
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.
#
#                                        text_wo_punct  \
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist y...
# 4                                     sprintcare did
#
#                                     text_wo_stopfreq  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                 text_wo_stopfreqrare  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                         text_stemmed  \
# 0  115712 understand would like assist would need...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click messag ...
# 4                                      sprintcar did
#
#                                      text_lemmatized
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private message one re...
# 3  115712 please send u private message assist yo...
# 4                                     sprintcare did

# %%
df.head(25)
# Out:
#                                                  text  \
# 0   @115712 I understand. I would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare I have sent several private messag...
# 3   @115712 Please send us a Private Message so th...
# 4                                  @sprintcare I did.
# 5   @115712 Can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 This is saddening to hear. Please shoo...
# 8   @sprintcare You gonna magically change your co...
# 9   @115713 We understand your concerns and we'd l...
# 10  @sprintcare Since I signed up with you....Sinc...
# 11  @115713 H there! We'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 Please send me a private message so th...
# 14  @115714 whenever I contact customer support, t...
# 15         @115716 What information is incorrect? ^JK
# 16  @Ask_Spectrum Would you like me to email you a...
# 17  @115716 Our department is part of the corporat...
# 18  @Ask_Spectrum I received this from your corpor...
# 19                          @115716 No thank you. ^JK
# 20  @Ask_Spectrum The correct way to do it is via ...
# 21  @Ask_Spectrum That is INCORRECT information I ...
# 22  @115716 The information pertaining to the acco...
# 23  actually that's a broken link you sent me and ...
# 24  @115717 Hello, My apologies for any frustratio...
#
#                                            text_lower  \
# 0   @115712 i understand. i would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare i have sent several private messag...
# 3   @115712 please send us a private message so th...
# 4                                  @sprintcare i did.
# 5   @115712 can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 this is saddening to hear. please shoo...
# 8   @sprintcare you gonna magically change your co...
# 9   @115713 we understand your concerns and we'd l...
# 10  @sprintcare since i signed up with you....sinc...
# 11  @115713 h there! we'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 please send me a private message so th...
# 14  @115714 whenever i contact customer support, t...
# 15         @115716 what information is incorrect? ^jk
# 16  @ask_spectrum would you like me to email you a...
# 17  @115716 our department is part of the corporat...
# 18  @ask_spectrum i received this from your corpor...
# 19                          @115716 no thank you. ^jk
# 20  @ask_spectrum the correct way to do it is via ...
# 21  @ask_spectrum that is incorrect information i ...
# 22  @115716 the information pertaining to the acco...
# 23  actually that's a broken link you sent me and ...
# 24  @115717 hello, my apologies for any frustratio...
#
#                                          text_wo_stop  \
# 0   @115712 understand. would like assist you. wou...
# 1                                 @sprintcare propose
# 2   @sprintcare sent several private messages one ...
# 3   @115712 please send us private message assist ...
# 4                                    @sprintcare did.
# 5   @115712 please send us private message, gain d...
# 6                  @sprintcare worst customer service
# 7   @115713 saddening hear. please shoot us dm, lo...
# 8   @sprintcare gonna magically change connectivit...
# 9   @115713 understand concerns we'd like please s...
# 10        @sprintcare since signed you....since day 1
# 11  @115713 h there! we'd definitely like work thi...
# 12  @115714 y’all lie “great” connection. 5 bars l...
# 13  @115715 please send private message send link ...
# 14  @115714 whenever contact customer support, tel...
# 15                 @115716 information incorrect? ^jk
# 16  @ask_spectrum would like email copy one since ...
# 17  @115716 department part corporate office. part...
# 18  @ask_spectrum received corporate office would ...
# 19                             @115716 thank you. ^jk
# 20  @ask_spectrum correct way via ocs account take...
# 21  @ask_spectrum incorrect information form front...
# 22  @115716 information pertaining account assumpt...
# 23  actually that's broken link sent incorrect inf...
# 24  @115717 hello, apologies frustrations inconven...
#
#                                         text_wo_punct  \
# 0   115712 understand would like assist you would ...
# 1                                  sprintcare propose
# 2   sprintcare sent several private messages one r...
# 3   115712 please send us private message assist y...
# 4                                      sprintcare did
# 5   115712 please send us private message gain det...
# 6                   sprintcare worst customer service
# 7   115713 saddening hear please shoot us dm look ...
# 8   sprintcare gonna magically change connectivity...
# 9   115713 understand concerns wed like please sen...
# 10             sprintcare since signed yousince day 1
# 11  115713 h there wed definitely like work this l...
# 12  115714 y’all lie “great” connection 5 bars lte...
# 13  115715 please send private message send link a...
# 14  115714 whenever contact customer support tell ...
# 15                    115716 information incorrect jk
# 16  askspectrum would like email copy one since sp...
# 17  115716 department part corporate office partic...
# 18  askspectrum received corporate office would li...
# 19                                115716 thank you jk
# 20  askspectrum correct way via ocs account takeov...
# 21  askspectrum incorrect information form front f...
# 22  115716 information pertaining account assumpti...
# 23  actually thats broken link sent incorrect info...
# 24  115717 hello apologies frustrations inconvenie...
#
#                                      text_wo_stopfreq  \
# 0   115712 understand would like assist would need...
# 1                                  sprintcare propose
# 2   sprintcare sent several private messages one r...
# 3   115712 send private message assist click ‘mess...
# 4                                      sprintcare did
# 5    115712 send private message gain details account
# 6                   sprintcare worst customer service
# 7                 115713 saddening hear shoot look kc
# 8   sprintcare gonna magically change connectivity...
# 9   115713 understand concerns wed like send direc...
# 10             sprintcare since signed yousince day 1
# 11  115713 h there wed definitely like work this l...
# 12  115714 y’all lie “great” connection 5 bars lte...
# 13  115715 send private message send link access a...
# 14  115714 whenever contact customer support tell ...
# 15                    115716 information incorrect jk
# 16  askspectrum would like email copy one since sp...
# 17  115716 department part corporate office partic...
# 18  askspectrum received corporate office would li...
# 19                                    115716 thank jk
# 20  askspectrum correct way via ocs account takeov...
# 21  askspectrum incorrect information form front f...
# 22  115716 information pertaining account assumpti...
# 23  actually thats broken link sent incorrect info...
# 24  115717 hello apologies frustrations inconvenie...
#
#                                  text_wo_stopfreqrare  \
# 0   115712 understand would like assist would need...
# 1                                  sprintcare propose
# 2   sprintcare sent several private messages one r...
# 3   115712 send private message assist click ‘mess...
# 4                                      sprintcare did
# 5    115712 send private message gain details account
# 6                   sprintcare worst customer service
# 7                 115713 saddening hear shoot look kc
# 8   sprintcare gonna magically change connectivity...
# 9   115713 understand concerns wed like send direc...
# 10             sprintcare since signed yousince day 1
# 11  115713 h there wed definitely like work this l...
# 12  115714 y’all lie “great” connection 5 bars lte...
# 13  115715 send private message send link access a...
# 14  115714 whenever contact customer support tell ...
# 15                    115716 information incorrect jk
# 16  askspectrum would like email copy one since sp...
# 17  115716 department part corporate office partic...
# 18  askspectrum received corporate office would li...
# 19                                    115716 thank jk
# 20  askspectrum correct way via ocs account takeov...
# 21  askspectrum incorrect information form front f...
# 22  115716 information pertaining account assumpti...
# 23  actually thats broken link sent incorrect info...
# 24  115717 hello apologies frustrations inconvenie...
#
#                                          text_stemmed  \
# 0   115712 understand would like assist would need...
# 1                                    sprintcar propos
# 2   sprintcar sent sever privat messag one respond...
# 3   115712 send privat messag assist click messag ...
# 4                                       sprintcar did
# 5       115712 send privat messag gain detail account
# 6                       sprintcar worst custom servic
# 7                    115713 sadden hear shoot look kc
# 8   sprintcar gonna magic chang connect whole fami...
# 9   115713 understand concern wed like send direct...
# 10                  sprintcar sinc sign yousinc day 1
# 11  115713 h there wed definit like work this long...
# 12  115714 y'all lie “great” connect 5 bar lte sti...
# 13  115715 send privat messag send link access acc...
# 14  115714 whenev contact custom support tell shor...
# 15                         115716 inform incorrect jk
# 16  askspectrum would like email copi one sinc spe...
# 17  115716 depart part corpor offic particular are...
# 18    askspectrum receiv corpor offic would like copi
# 19                                    115716 thank jk
# 20  askspectrum correct way via oc account takeov ...
# 21  askspectrum incorrect inform form front fax ov...
# 22  115716 inform pertain account assumpt correct ...
# 23  actual that broken link sent incorrect inform ...
# 24  115717 hello apolog frustrat inconveni i'd hap...
#
#                                       text_lemmatized
# 0   115712 understand would like assist you would ...
# 1                                  sprintcare propose
# 2   sprintcare sent several private message one re...
# 3   115712 please send u private message assist yo...
# 4                                      sprintcare did
# 5   115712 please send u private message gain deta...
# 6                   sprintcare worst customer service
# 7   115713 saddening hear please shoot u dm look y...
# 8   sprintcare gonna magically change connectivity...
# 9   115713 understand concern wed like please send...
# 10             sprintcare since signed yousince day 1
# 11  115713 h there wed definitely like work this l...
# 12  115714 y’all lie “great” connection 5 bar lte ...
# 13  115715 please send private message send link a...
# 14  115714 whenever contact customer support tell ...
# 15                    115716 information incorrect jk
# 16  askspectrum would like email copy one since sp...
# 17  115716 department part corporate office partic...
# 18  askspectrum received corporate office would li...
# 19                                115716 thank you jk
# 20  askspectrum correct way via ocs account takeov...
# 21  askspectrum incorrect information form front f...
# 22  115716 information pertaining account assumpti...
# 23  actually thats broken link sent incorrect info...
# 24  115717 hello apology frustration inconvenience...

# %%
lemmatizer.lemmatize("running")
# Out:
# 'running'

# %%
lemmatizer.lemmatize("running", "v") # v for verb
# Out:
# 'run'

# %%
print("Word is : stripes")
print("Lemma result for verb : ",lemmatizer.lemmatize("stripes", 'v'))
print("Lemma result for noun : ",lemmatizer.lemmatize("stripes", 'n'))
# Out:
# Word is : stripes
# Lemma result for verb :  strip
# Lemma result for noun :  strip

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/vijay/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

df["text_lemmatized"] = df["text_wo_punct"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         text_wo_stop  \
# 0  @115712 understand. would like assist you. wou...
# 1                                @sprintcare propose
# 2  @sprintcare sent several private messages one ...
# 3  @115712 please send us private message assist ...
# 4                                   @sprintcare did.
#
#                                        text_wo_punct  \
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist y...
# 4                                     sprintcare did
#
#                                     text_wo_stopfreq  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                 text_wo_stopfreqrare  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                     sprintcare did
#
#                                         text_stemmed  \
# 0  115712 understand would like assist would need...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click messag ...
# 4                                      sprintcar did
#
#                                      text_lemmatized
# 0  115712 understand would like assist you would ...
# 1                                 sprintcare propose
# 2  sprintcare send several private message one re...
# 3  115712 please send u private message assist yo...
# 4                                      sprintcare do

# %%
df.head(25)
# Out:
#                                                  text  ...                                    text_lemmatized
# 0   @115712 I understand. I would like to assist y...  ...  115712 understand would like assist you would ...
# 1       @sprintcare and how do you propose we do that  ...                                 sprintcare propose
# 2   @sprintcare I have sent several private messag...  ...  sprintcare send several private message one re...
# 3   @115712 Please send us a Private Message so th...  ...  115712 please send u private message assist yo...
# 4                                  @sprintcare I did.  ...                                      sprintcare do
# 5   @115712 Can you please send us a private messa...  ...  115712 please send u private message gain deta...
# 6           @sprintcare is the worst customer service  ...                    sprintcare bad customer service
# 7   @115713 This is saddening to hear. Please shoo...  ...   115713 sadden hear please shoot u dm look you kc
# 8   @sprintcare You gonna magically change your co...  ...  sprintcare gonna magically change connectivity...
# 9   @115713 We understand your concerns and we'd l...  ...  115713 understand concern wed like please send...
# 10  @sprintcare Since I signed up with you....Sinc...  ...               sprintcare since sign yousince day 1
# 11  @115713 H there! We'd definitely like to work ...  ...  115713 h there wed definitely like work this l...
# 12  @115714 y’all lie about your “great” connectio...  ...  115714 y’all lie “great” connection 5 bar lte ...
# 13  @115715 Please send me a private message so th...  ...  115715 please send private message send link a...
# 14  @115714 whenever I contact customer support, t...  ...  115714 whenever contact customer support tell ...
# 15         @115716 What information is incorrect? ^JK  ...                    115716 information incorrect jk
# 16  @Ask_Spectrum Would you like me to email you a...  ...  askspectrum would like email copy one since sp...
# 17  @115716 Our department is part of the corporat...  ...  115716 department part corporate office partic...
# 18  @Ask_Spectrum I received this from your corpor...  ...  askspectrum receive corporate office would lik...
# 19                          @115716 No thank you. ^JK  ...                                115716 thank you jk
# 20  @Ask_Spectrum The correct way to do it is via ...  ...  askspectrum correct way via ocs account takeov...
# 21  @Ask_Spectrum That is INCORRECT information I ...  ...  askspectrum incorrect information form front f...
# 22  @115716 The information pertaining to the acco...  ...  115716 information pertain account assumption ...
# 23  actually that's a broken link you sent me and ...  ...  actually thats broken link send incorrect info...
# 24  @115717 Hello, My apologies for any frustratio...  ...  115717 hello apology frustration inconvenience...
#
# [25 rows x 8 columns]

# %% [markdown]
# 8. Remove Emojis

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

remove_emoji("game is on 🔥🔥")
# Out:
# 'game is on '

# %% [markdown]
# 10. Remove URLs

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

# %%
text = "Driverless AI NLP blog post on https://www.h2o.ai/blog/detecting-sarcasm-is-difficult-but-ai-may-have-an-answer/"
remove_urls(text)
# Out:
# 'Driverless AI NLP blog post on '

# %%
text = "Want to know more. Checkout www.h2o.ai for additional information"
remove_urls(text)
# Out:
# 'Want to know more. Checkout  for additional information'

# %% [markdown]
# 11. Remove HTML tags

# %%
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

text = """<div>
<h1> H2O</h1>
<p> AutoML</p>
<a href="https://www.h2o.ai/products/h2o-driverless-ai/"> Driverless AI</a>
</div>"""

print(remove_html(text))
# Out:
#  H2O
#  AutoML
#  Driverless AI

# %% [markdown]
# You could also practise with any other dataset of your choice and apply such practices
